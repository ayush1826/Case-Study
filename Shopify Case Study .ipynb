# %%
# %matplotlib inline 
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
sheet_id ='16i38oonuX1y1g7C_UAmiK9GkY7cS-64DfiDMNiR41LM'

df = pd.read_csv(f"https://docs.google.com/spreadsheets/d/{sheet_id}/export?format=csv")

print(df)
# Out:
#       order_id  shop_id  user_id  order_amount  total_items payment_method  \
# 0            1       53      746           224            2           cash
# 1            2       92      925            90            1           cash
# 2            3       44      861           144            1           cash
# 3            4       18      935           156            1    credit_card
# 4            5       18      883           156            1    credit_card
# ...        ...      ...      ...           ...          ...            ...
# 4995      4996       73      993           330            2          debit
# 4996      4997       48      789           234            2           cash
# 4997      4998       56      867           351            3           cash
# 4998      4999       60      825           354            2    credit_card
# 4999      5000       44      734           288            2          debit
#
#                created_at
# 0     2017-03-13 12:36:56
# ...

# %%
df.head()
# Out:
#    order_id  shop_id  user_id  order_amount  total_items payment_method  \
# 0         1       53      746           224            2           cash
# 1         2       92      925            90            1           cash
# 2         3       44      861           144            1           cash
# 3         4       18      935           156            1    credit_card
# 4         5       18      883           156            1    credit_card
#
#             created_at
# 0  2017-03-13 12:36:56
# 1  2017-03-03 17:38:52
# 2   2017-03-14 4:23:56
# 3  2017-03-26 12:43:37
# 4   2017-03-01 4:35:11

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        5000 non-null   int64
#  1   shop_id         5000 non-null   int64
#  2   user_id         5000 non-null   int64
#  3   order_amount    5000 non-null   int64
#  4   total_items     5000 non-null   int64
#  5   payment_method  5000 non-null   object
#  6   created_at      5000 non-null   object
# dtypes: int64(5), object(2)
# memory usage: 273.6+ KB

# %%
df.columns
# Out:
# Index(['order_id', 'shop_id', 'user_id', 'order_amount', 'total_items',
#        'payment_method', 'created_at'],
#       dtype='object')

# %%
df.describe()
# Out:
#           order_id      shop_id      user_id   order_amount  total_items
# count  5000.000000  5000.000000  5000.000000    5000.000000   5000.00000
# mean   2500.500000    50.078800   849.092400    3145.128000      8.78720
# std    1443.520003    29.006118    87.798982   41282.539349    116.32032
# min       1.000000     1.000000   607.000000      90.000000      1.00000
# 25%    1250.750000    24.000000   775.000000     163.000000      1.00000
# 50%    2500.500000    50.000000   849.000000     284.000000      2.00000
# 75%    3750.250000    75.000000   925.000000     390.000000      3.00000
# max    5000.000000   100.000000   999.000000  704000.000000   2000.00000

# %%
sns.boxplot(df.order_amount)
# Out:
# <AxesSubplot:xlabel='order_amount'>

# %%
sns.boxplot(df['total_items'])
# Out:
# <AxesSubplot:xlabel='total_items'>

# %%
sns.catplot(x="payment_method", kind="count", palette="ch:.25", data=df)

# %%
#Scale purchases to give even weight to total_items
df['avg_orders_val'] = df['order_amount'] / df['total_items']

# %%
df.describe()
# Out:
#           order_id      shop_id      user_id   order_amount  total_items  \
# count  5000.000000  5000.000000  5000.000000    5000.000000   5000.00000
# mean   2500.500000    50.078800   849.092400    3145.128000      8.78720
# std    1443.520003    29.006118    87.798982   41282.539349    116.32032
# min       1.000000     1.000000   607.000000      90.000000      1.00000
# 25%    1250.750000    24.000000   775.000000     163.000000      1.00000
# 50%    2500.500000    50.000000   849.000000     284.000000      2.00000
# 75%    3750.250000    75.000000   925.000000     390.000000      3.00000
# max    5000.000000   100.000000   999.000000  704000.000000   2000.00000
#
#        avg_orders_val
# count     5000.000000
# mean       387.742800
# std       2441.963725
# min         90.000000
# 25%        133.000000
# 50%        153.000000
# 75%        169.000000
# max      25725.000000

# %%
df[df['order_amount'] > 600000]
# Out:
#       order_id  shop_id  user_id  order_amount  total_items payment_method  \
# 15          16       42      607        704000         2000    credit_card
# 60          61       42      607        704000         2000    credit_card
# 520        521       42      607        704000         2000    credit_card
# 1104      1105       42      607        704000         2000    credit_card
# 1362      1363       42      607        704000         2000    credit_card
# 1436      1437       42      607        704000         2000    credit_card
# 1562      1563       42      607        704000         2000    credit_card
# 1602      1603       42      607        704000         2000    credit_card
# 2153      2154       42      607        704000         2000    credit_card
# 2297      2298       42      607        704000         2000    credit_card
# 2835      2836       42      607        704000         2000    credit_card
# ...

# %%
#As we see that the order amount is way too high so removing this will get us good result as it can consider as an outlier. 

filtered_dataset = df[df['order_amount'] != 704000]

# %%
filtered_dataset.describe()
# Out:
#           order_id      shop_id      user_id   order_amount  total_items  \
# count  4983.000000  4983.000000  4983.000000    4983.000000   4983.00000
# mean   2501.060405    50.106362   849.918322     754.091913      1.99398
# std    1443.090253    29.051718    86.800308    5314.092293      0.98318
# min       1.000000     1.000000   700.000000      90.000000      1.00000
# 25%    1250.500000    24.000000   776.000000     163.000000      1.00000
# 50%    2502.000000    50.000000   850.000000     284.000000      2.00000
# 75%    3750.500000    75.000000   925.000000     390.000000      3.00000
# max    5000.000000   100.000000   999.000000  154350.000000      8.00000
#
#        avg_orders_val
# count      4983.00000
# mean        387.86474
# std        2446.12562
# min          90.00000
# 25%         133.00000
# 50%         153.00000
# 75%         168.00000
# max       25725.00000

# %%
sns.boxplot(df.avg_orders_val)
# Out:
# <AxesSubplot:xlabel='avg_orders_val'>

# %%
filtered_dataset1 = df[df['avg_orders_val'] != 25725]

# %%
filtered_dataset1.describe()
# Out:
#           order_id      shop_id      user_id   order_amount  total_items  \
# count  4954.000000  4954.000000  4954.000000    4954.000000  4954.000000
# mean   2498.990916    49.819540   848.919257    2717.367784     8.851029
# std    1444.498907    29.014845    87.846007   41155.996469   116.857286
# min       1.000000     1.000000   607.000000      90.000000     1.000000
# 25%    1248.250000    24.000000   775.000000     163.000000     1.000000
# 50%    2494.500000    50.000000   849.000000     284.000000     2.000000
# 75%    3750.750000    74.000000   925.000000     390.000000     3.000000
# max    5000.000000   100.000000   999.000000  704000.000000  2000.000000
#
#        avg_orders_val
# count     4954.000000
# mean       152.475575
# std         31.260218
# min         90.000000
# 25%        132.000000
# 50%        153.000000
# 75%        168.000000
# max        352.000000

# %%
filtered_dataset2 = df[(df['order_amount'] != 704000) & (df['avg_orders_val'] != 25725)]

# %%
filtered_dataset2.describe()
# Out:
#           order_id      shop_id      user_id  order_amount  total_items  \
# count  4937.000000  4937.000000  4937.000000   4937.000000  4937.000000
# mean   2499.551347    49.846465   849.752279    302.580514     1.994734
# std    1444.069407    29.061131    86.840313    160.804912     0.982821
# min       1.000000     1.000000   700.000000     90.000000     1.000000
# 25%    1248.000000    24.000000   775.000000    163.000000     1.000000
# 50%    2497.000000    50.000000   850.000000    284.000000     2.000000
# 75%    3751.000000    74.000000   925.000000    387.000000     3.000000
# max    5000.000000   100.000000   999.000000   1760.000000     8.000000
#
#        avg_orders_val
# count     4937.000000
# mean       151.788536
# std         29.034215
# min         90.000000
# 25%        132.000000
# 50%        153.000000
# 75%        166.000000
# max        352.000000

# %%
val = ['order_amount','total_items', 'avg_orders_val']

filtered_dataset2.boxplot(val)
# Out:
# <AxesSubplot:>

# %%
filtered_dataset2[filtered_dataset2['order_amount'] > 750]
# Out:
#       order_id  shop_id  user_id  order_amount  total_items payment_method  \
# 99         100       18      752           780            5           cash
# 136        137       15      961           765            5    credit_card
# 219        220       23      884           780            5    credit_card
# 222        223       96      829           765            5          debit
# 259        260       99      963           780            4    credit_card
# ...        ...      ...      ...           ...          ...            ...
# 4905      4906       38      748           760            4          debit
# 4927      4928       74      849           765            5           cash
# 4952      4953       26      786           880            5           cash
# 4958      4959       70      711           865            5    credit_card
# 4980      4981       50      942           772            4    credit_card
#
#                created_at  avg_orders_val  z_score
# ...

# %%
filtered_dataset2.groupby(filtered_dataset2['shop_id'])['avg_orders_val'].mean().reset_index().sort_values(by=['avg_orders_val'], ascending = False).head()
# Out:
#     shop_id  avg_orders_val
# 41       42           352.0
# 11       12           201.0
# 87       89           196.0
# 97       99           195.0
# 49       50           193.0

# %%
filtered_dataset2['z_score'] = (filtered_dataset2['order_amount'] - 3145.13) / 41282.54
filtered_dataset2['z_score'] = filtered_dataset2['z_score'].round(3)
filtered_dataset2.head()
# Out:
#    order_id  shop_id  user_id  order_amount  total_items payment_method  \
# 0         1       53      746           224            2           cash
# 1         2       92      925            90            1           cash
# 2         3       44      861           144            1           cash
# 3         4       18      935           156            1    credit_card
# 4         5       18      883           156            1    credit_card
#
#             created_at  avg_orders_val  z_score
# 0  2017-03-13 12:36:56           112.0   -0.071
# 1  2017-03-03 17:38:52            90.0   -0.074
# 2   2017-03-14 4:23:56           144.0   -0.073
# 3  2017-03-26 12:43:37           156.0   -0.072
# 4   2017-03-01 4:35:11           156.0   -0.072

# %%
filtered_dataset2.order_amount.quantile([0.5,0.6,0.7,0.9,0.95,0.99])
# Out:
# 0.50    284.0
# 0.60    320.0
# 0.70    354.0
# 0.90    520.0
# 0.95    592.0
# 0.99    780.0
# Name: order_amount, dtype: float64

# %%
#As we see from the quantile biffurcation, we can not directly remove the outliers becuse it will going to effect the final result.
#As in the data, the values are highly skewed and have many outliers values which affects the final result. 
#We have to closely see the data and understand the final values which is affecting the result and remove them.
# we used z-score and outliers detection to reduced down the data and cut short the value of the shoes.

# the final price is $154
